# %%
import sys, platform, os

print("Python:", sys.version)
print("Platform:", platform.platform())
print("CWD:", os.getcwd())
# Out:
# Python: 3.10.6 (tags/v3.10.6:9c7b4bd, Aug  1 2022, 21:53:49) [MSC v.1932 64 bit (AMD64)]
# Platform: Windows-10-10.0.19045-SP0
# CWD: d:\Downloads\nfl_player_detection\notebooks

# %%
# !nvidia-smi
# Out:
# Tue Jan 27 23:04:58 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.57                 Driver Version: 581.57         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3080      WDDM  |   00000000:06:00.0  On |                  N/A |
# |  0%   44C    P8             24W /  320W |    2706MiB /  10240MiB |     23%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1848    C+G   ...r\frontend\Docker Desktop.exe      N/A      |
# |    0   N/A  N/A            2076    C+G   ...h_cw5n1h2txyewy\SearchApp.exe      N/A      |
# |    0   N/A  N/A            2628    C+G   ...64__8wekyb3d8bbwe\Copilot.exe      N/A      |
# |    0   N/A  N/A           10308    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           10316    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           11620    C+G   ...cord\app-1.0.9221\Discord.exe      N/A      |
# |    0   N/A  N/A           11832    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           12336    C+G   ...h_cw5n1h2txyewy\SearchApp.exe      N/A      |
# |    0   N/A  N/A           13668    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           13924    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           17848    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           18988      C   ...roadcast\NVIDIA Broadcast.exe      N/A      |
# |    0   N/A  N/A           19208    C+G   ...roadcast\NVIDIA Broadcast.exe      N/A      |
# |    0   N/A  N/A           20476    C+G   ....0.3719.93\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           23320    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           23832    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           27040    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           27312    C+G   ...4__8wekyb3d8bbwe\Video.UI.exe      N/A      |
# |    0   N/A  N/A           29056    C+G   ...\cef.win64\steamwebhelper.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch

print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
print("cuda version (torch):", torch.version.cuda)
print("gpu name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else None)

if torch.cuda.is_available():
    free, total = torch.cuda.mem_get_info()
    print(f"GPU free/total: {free/1e9:.2f} GB / {total/1e9:.2f} GB")
# Out:
# torch: 2.6.0+cu124
# cuda available: True
# cuda version (torch): 12.4
# gpu name: NVIDIA GeForce RTX 3080
# GPU free/total: 9.51 GB / 10.74 GB
